# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y = [10,20,30,45,50]

plt.plot(x,y)
plt.show()

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
# with color
c = ["r","y","g","b","k"]
plt.bar(x,y,color=c)
# Out:
# <BarContainer object of 5 artists>
